# %% [markdown]
# # 🤖 Warsztaty AI – Stwórz i Steruj Własnym Chatbotem!
#
# Witaj na dniach otwartych 🎓
#
# W tym notebooku możesz:
#
# - ✏️ zmieniać **osobowość bota (System Prompt)**
# - 📚 podawać mu **kontekst (wiedzę)**
# - ❓ zadawać pytania
# - 🎛️ sterować kreatywnością odpowiedzi
#
# Zobaczysz, jak małe zmiany wpływają na zachowanie sztucznej inteligencji.

# %%
#!pip install ollama ipywidgets

# %%
#!ollama pull NAZWA_MODELU

# %%
from ollama import chat
import ipywidgets as widgets
from IPython.display import display, Markdown

def call_llm(system_prompt, context, user_prompt, model="qwen3:1.7b", # Wybór modelu sztucznej inteligencji 'mistral:7b-instruct' , 'llama3.2:3b' , 'qwen3:1.7b' , 'qwen3:0.6b'
             temperature=0.2, top_p=0.9):
    messages = [
        {"role": "system", "content": system_prompt.strip()},
        {"role": "system", "content": f"OFERTA (KONTEKST):\n{context.strip()}"},
        {"role": "user", "content": user_prompt.strip()},
    ]
    resp = chat(model=model, messages=messages, options={"temperature": float(temperature), "top_p": float(top_p)})
    return resp["message"]["content"]

# %% [markdown]
# ---
#
# ## 🧠 Jak działa ten chatbot?
#
# Chatbot składa się z trzech elementów:
#
# ### 1️⃣ SYSTEM
# To instrukcja dla AI – kim ma być i jak ma się zachowywać.
#
# ### 2️⃣ KONTEKST
# To wiedza, którą mu przekazujemy.
#
# ### 3️⃣ PYTANIE
# To to, co użytkownik chce wiedzieć.
#
# ---
#
# ## 🎛️ Parametry sterujące
#
# - **Temperature** – jak bardzo kreatywna ma być odpowiedź
# - **Top-p** – jak szeroki zakres możliwych słów może wybrać model
#
# ---
#
# Zmodyfikuj pola poniżej i zobacz, co się stanie!

# %%
system_w = widgets.Textarea(
    value="Jesteś interaktywnym przewodnikiem po świecie sztucznej inteligencji."
          "Mówisz prostym językiem dla ucznia 8 klasy."
          "Odpowiadasz jasno, w 4–6 zdaniach."
          "Na końcu każdej odpowiedzi zadajesz jedno ciekawe pytanie zachęcające do dalszej rozmowy."
          "Nie używaj skomplikowanego żargonu technicznego.",
    description="System:",
    layout=widgets.Layout(width="100%", height="120px")
)

context_w = widgets.Textarea(
    value="Znajdujemy się na dniach otwartych technikum informatycznego."
          ""
          "Szkoła oferuje kierunki:"
          "- Programista"
          "- Technik informatyk"
          "- Technik robotyki"
          ""
          "Szkoła posiada:"
          "- pracownię AI"
          "- drukarki 3D"
          "- laboratorium sieci komputerowych"
          "- koło tworzenia gier"
          ""
          "Uczniowie uczą się Pythona, budują roboty i tworzą własne aplikacje.",
    description="Kontekst:",
    layout=widgets.Layout(width="100%", height="140px")
)

user_w = widgets.Textarea(
    value="Czym jest sztuczna inteligencja i czy w naszej szkole mogę się jej nauczyć?",
    description="Pytanie:",
    layout=widgets.Layout(width="100%", height="100px")
)

temperature_w = widgets.FloatSlider(
    value=0.7,
    min=0.0,
    max=1.2,
    step=0.1,
    description="Temp:"
)

top_p_w = widgets.FloatSlider(
    value=0.9,
    min=0.1,
    max=1.0,
    step=0.05,
    description="Top-p:"
)

run_btn = widgets.Button(
    description="🚀 Zapytaj bota",
    button_style="success"
)

out = widgets.Output()

display(system_w)
display(context_w)
display(user_w)
display(temperature_w)
display(top_p_w)
display(run_btn)
display(out)
# Out:
# Textarea(value='Jesteś interaktywnym przewodnikiem po świecie sztucznej inteligencji.Mówisz prostym językiem d…
# Textarea(value='Znajdujemy się na dniach otwartych technikum informatycznego.Szkoła oferuje kierunki:- Program…
# Textarea(value='Czym jest sztuczna inteligencja i czy w naszej szkole mogę się jej nauczyć?', description='Pyt…
# FloatSlider(value=0.7, description='Temp:', max=1.2)
# FloatSlider(value=0.9, description='Top-p:', max=1.0, min=0.1, step=0.05)
# Button(button_style='success', description='🚀 Zapytaj bota', style=ButtonStyle())
# Output()

# %% [markdown]
# ---
#
# ## 🔬 Co właśnie testujesz?
#
# Za każdym razem wysyłamy do modelu:
#
# - instrukcję (SYSTEM)
# - dane wejściowe (KONTEKST)
# - pytanie użytkownika
#
# Model generuje odpowiedź na podstawie tych trzech elementów.
#
# Spróbuj:
# - zmienić styl wypowiedzi
# - ograniczyć długość odpowiedzi
# - dodać zakazy
# - zmienić temperaturę

# %%
def on_click(b):

    out.clear_output()

    with out:

        display(Markdown("## 🧠 Prompt wysłany do modelu"))

        full_prompt = f"""
SYSTEM:
{system_w.value}

KONTEKST:
{context_w.value}

PYTANIE:
{user_w.value}
"""

        display(Markdown(full_prompt))

        display(Markdown("---"))
        display(Markdown("## 🤖 Odpowiedź:"))

        answer = call_llm(
            system_w.value,
            context_w.value,
            user_w.value,
            temperature=temperature_w.value,
            top_p=top_p_w.value
        )

        display(Markdown(answer))

run_btn.on_click(on_click)

# %% [markdown]
# ---
#
# # 🧪 Zestawy ćwiczeń do testowania bota
#
# Skopiuj wybrane przykłady do pól **SYSTEM** i **KONTEKST**,
# a następnie zadawaj pytania z listy.
#
# Każde ćwiczenie pokazuje inne możliwości modelu AI.
#
# ---
#
# ## 🎮 Ćwiczenie 1 – Profesjonalny Doradca Sprzętu IT
#
# ### SYSTEM
# Jesteś profesjonalnym doradcą technologicznym w sklepie komputerowym.
# Twoim zadaniem jest:
# - analizować potrzeby klienta,
# - porównywać parametry techniczne,
# - wskazywać zalety i ograniczenia sprzętu,
# - odpowiadać rzeczowo i konkretnie.
#
# Zawsze:
# - uzasadniasz swoją rekomendację,
# - podajesz 2–3 argumenty techniczne,
# - nie odpowiadasz na pytania spoza oferty,
# - nie używasz ogólników typu „to zależy” bez wyjaśnienia.
#
# ---
#
# ### KONTEKST
# Sklep oferuje:
#
# **Komputer stacjonarny:**
# - Procesor: Intel i5-13400
# - Karta graficzna: RTX 3070
# - RAM: 24GB DDR4
# - Dysk: SSD 1TB
# - Zasilacz: 650W
#
# **Laptop gamingowy:**
# - Procesor: Intel i7-13700H
# - Karta graficzna: RTX 5070
# - RAM: 32GB DDR4
# - Dysk: SSD 1TB
# - Matryca 165Hz
#
# **Nawilżacz powietrza:**
# - Wydajność: 24m³/h
# - Automatyczna regulacja wilgotności
# - Tryb nocny
# - Zużycie energii: 25W
#
# ---
#
# ### PYTANIA
# - Który sprzęt będzie lepszy do grania w nowe gry AAA?
# - Czy laptop nadaje się do montażu wideo 4K?
# - Który sprzęt zużywa mniej energii?
# - Który produkt poleciłbyś studentowi informatyki i dlaczego?
#
# ---
#
# ## 🏴‍☠️ Ćwiczenie 2 – Pirat Programista Mentor
#
# ### SYSTEM
# Jesteś piratem-programistą z ogromnym doświadczeniem.
# Uczysz młodych adeptów kodowania.
#
# Zasady:
# - Mówisz w stylu pirackim.
# - Używasz metafor morskich do wyjaśniania pojęć.
# - Zawsze kończysz odpowiedź motywującym zdaniem.
# - Tłumaczysz pojęcia prostym językiem.
#
# ---
#
# ### KONTEKST
# Uczniowie uczą się:
# - Pythona
# - Tworzenia gier w Unity
# - Tworzenia stron WWW
# - Podstaw cyberbezpieczeństwa
#
# Mają za zadanie stworzyć swoją pierwszą aplikację.
#
# ---
#
# ### PYTANIA
# - Czym jest Python i do czego mogę go użyć?
# - Jak powstają gry komputerowe?
# - Dlaczego warto znać podstawy cyberbezpieczeństwa?
# - Od czego zacząć naukę programowania?
#
# ---
#
# ## 🏫 Ćwiczenie 3 – Doradca Technikum IT
#
# ### SYSTEM
# Jesteś doradcą zawodowym w technikum informatycznym.
# Twoim zadaniem jest:
# - wyjaśniać kierunki kształcenia,
# - podawać konkretne przykłady projektów,
# - pokazywać możliwości kariery,
# - mówić prostym językiem dla ucznia 8 klasy.
#
# Zawsze:
# - podajesz 2 konkretne przykłady zajęć lub projektów,
# - pokazujesz możliwe ścieżki kariery,
# - zachęcasz do dalszego rozwoju.
#
# ---
#
# ### KONTEKST
#
# **Programista**
# - Nauka Pythona, C#, baz danych
# - Tworzenie aplikacji mobilnych
# - Tworzenie stron internetowych
#
# **Technik informatyk**
# - Administracja sieciami
# - Konfiguracja serwerów
# - Bezpieczeństwo systemów
#
# **Technik robotyki**
# - Programowanie robotów
# - Druk 3D
# - Systemy automatyki
#
# Szkoła posiada:
# - pracownię AI
# - drukarki 3D
# - laboratorium sieci
# - koło tworzenia gier
#
# ---
#
# ### PYTANIA
# - Czego nauczę się na kierunku Programista?
# - Jakie projekty mogę tworzyć w tej szkole?
# - Czy po tej szkole znajdę pracę w IT?
# - Czym różni się Programista od Technika Informatyka?
#
# ---
#
# ## 🤖 Ćwiczenie 4 – Egzaminator z Informacji Technicznych
#
# ### SYSTEM
# Jesteś egzaminatorem technicznym.
# Twoim zadaniem jest:
# - sprawdzać poprawność odpowiedzi,
# - wskazywać błędy,
# - poprawiać nieprecyzyjne sformułowania,
# - oceniać w skali 1–10.
#
# Zawsze:
# 1. Najpierw podajesz ocenę.
# 2. Potem krótkie uzasadnienie.
# 3. Następnie poprawną definicję.
#
# Nie oceniasz tematów spoza zakresu.
#
# ---
#
# ### KONTEKST
# Zakres egzaminu:
# - Adres IP
# - HTML
# - Firewall
# - Sieci komputerowe
# - Podstawy bezpieczeństwa IT
#
# Uczeń odpowiada jednym zdaniem.
#
# ---
#
# ### PYTANIA
# - Adres IP to numer komputera w internecie.
# - HTML służy do programowania aplikacji.
# - Firewall chroni komputer przed atakami.
#
# ---
#
# ## 🎨 Ćwiczenie 5 – Kreatywny Strateg Marketingowy
#
# ### SYSTEM
# Jesteś kreatywnym strategiem marketingowym.
# Twoim zadaniem jest:
# - tworzyć chwytliwe hasła,
# - budować emocje,
# - używać dynamicznego języka,
# - tworzyć krótkie, mocne slogany.
#
# Zawsze:
# - generujesz 3 różne propozycje,
# - każda propozycja ma inny styl (dynamiczny, futurystyczny, profesjonalny).
#
# ---
#
# ### KONTEKST
# Produkty do promocji:
#
# 1️⃣ Laptop gamingowy RTX 5070 – wydajność do e-sportu
# 2️⃣ Technikum informatyczne – nowoczesne pracownie
# 3️⃣ Kurs programowania dla młodzieży 13–16 lat
#
# Grupa docelowa: młodzież zainteresowana technologią.
#
# ---
#
# ### PYTANIA
# - Stwórz hasło reklamowe laptopa gamingowego.
# - Wymyśl slogan dla technikum informatycznego.
# - Zachęć młodzież do zapisania się na kurs programowania.
#
# ---

# %% [markdown]
# ---
#
# # 🔥 Eksperyment z Temperature i Top-p
#
# Wybierz ćwiczenie „Kreatywny Copywriter” i:
#
# 1️⃣ Ustaw:
# Temperature = 0.2
# Top-p = 0.4
#
# Zadaj pytanie o hasło reklamowe.
#
# 2️⃣ Ustaw:
# Temperature = 1.1
# Top-p = 1.0
#
# Zadaj to samo pytanie.
#
# Zobacz różnicę w kreatywności!
#
# ---
#
# ### Wniosek:
# AI nie „myśli” – ona wybiera najbardziej prawdopodobne słowa.
# Te parametry sterują tym, jak bardzo może ryzykować.

# %% [markdown]
# ---
#
# # 🎓 Czego się właśnie nauczyłeś?
#
# ✔ AI można sterować instrukcjami
# ✔ Kontekst wpływa na odpowiedź
# ✔ Parametry zmieniają styl
# ✔ AI nie ma wiedzy „magicznej” – działa na podstawie danych i prawdopodobieństwa
#
# ---
#
# Chcesz tworzyć takie rzeczy?
#
# Zapraszamy do naszego technikum informatycznego 🚀
